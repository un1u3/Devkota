# %%
class SelfAttention:

    # Single head of self-attentionm 

    # math breakdown
    # 1. Project input to Q,K,V 
    # 2. Compute attention scores: Q @ k^T
    # 3. Scale scores root(dk)
    # 4. Mask future tokens (for autoregressive generation)
    # 5. Softmax: convert int probablitites 
    # 6. Weighted Sum : attention_weights @ v

    def __init__(self, embedding_dim, head_dim):
        super().__init__()
        self.head_dim = head_dim

        # Linear projections 
        self.query = nn.Linear(embedding_dim,head_dim, bias= False)
        self.key = nn.Linear(embedding_dim,head_dim, bias= False)
        self.value = nn.Linear(embedding_dim,head_dim, bias= False)
        # casual mask (prevent looking at future tkens)
        # lowerr traingular matrix 

    def forward(self, x):
        batch, seq_len, emb_dim = x.shape 

        # step 1: Project to Q, K, V
        Q = self.query(x) 
        K = self.query(x) 
        V = self.query(x) 

        # step2: Compute attention scoare 
        #  Q @ K^T

        scores = Q @ K.transpose(-2, -1)

        # step 3 : Scale 
        scores = scores / (self.head_dim ** 0.5)

        # apply causal mask
        # make upper trangle -inf so when appled softamx it gives 0 
        mask = torch.tril(torch.ones(seq_len, seq_len))
        scores = scores.masked_fill(mask ==0, float('-inf'))

        # step 5: Softmax (get Probablitits)
        attention_weights = F.softmax(scores, dim=-1)


        # step 6;  Weighted sum of values 
        output = attention_weights @ V 

        return output, attention_weights
